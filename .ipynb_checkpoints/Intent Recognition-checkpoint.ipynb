# %%
import os

# Clash、VPN、V2Ray常用端口
os.environ["HTTPS_PROXY"] = "http://127.0.0.1:7890"
os.environ["ALL_PROXY"] = "socks5://127.0.0.1:7890"

# %%
os.environ.pop("HTTPS_PROXY", None)
os.environ.pop("ALL_PROXY", None)
# Out:
# 'socks5://127.0.0.1:7890'

# %%
import os
from langchain_community.chat_models import ChatZhipuAI
from dotenv import load_dotenv

load_dotenv()
model = ChatZhipuAI(model="glm-4-air-250414", temperature=0.5)

def recognise_intent(question):
    os.environ.pop("HTTPS_PROXY", None)
    os.environ.pop("ALL_PROXY", None)
    prompt = f"""
    你是一个用户意图识别专家，擅长分析用户对话，并识别出用户的意图。作为一个智能问答系统的关键组件，你的工作是：
    
    1. 分析用户对话，识别出用户的意图。
    2. 根据用户的意图，准确输出对应的意图标签。
    
    问答系统支持以下意图：
    
    - 查询政策信息
    - 查询招标信息
    - 查询商品信息
    - 查询企业信息
    
    ## 限制
    
    - 只输出意图标签，不要输出任何解释。
    - 不要输出意图标签之外的任何内容。
    - 如果无法识别出意图，请输出 `unknown`。
    """
    systemPrompts = [
        ("system", prompt),
    ]
    
    samples = [
        ("user", "香蕉可以空腹吃吗？"),
        ("assistant", "unknown"),
      
        # 积分查询
        ("user", "最新的三条政府采购公告"),
        ("assistant", "查询招标信息"),

        ("user", "招标失败怎么办"),
        ("assistant", "查询政策信息"),
        # 还可以在这继续将样本
        # 大模型会从样本中总结出规律，并应用到新对话中
    ]

    response = model.invoke(systemPrompts + samples + [("user", question)]).content
    return response.strip()

def if_sql(question):
    prompt = """
    你是一个数据库管理机器人，我需要你根据用户提出的问题，判断是否需要检索SQL数据库。你的工作是：

    1、分析用户问题，判断是否是语义问题，或者是逻辑/条件问题。
    2、准确输出判断结果：
        - 若需要使用SQL语句检索数据库，输出"True"
        - 若**不**需要使用SQL数据库，输出"False"
    
    通常来说，问题只要涉及多条数据（搜索整个表）可能需要sql检索，如果只是针对某一条数据（搜索一条数据）不需要查询SQL数据库。
    仅供参考，具体以实际问题为主。
    
    ## 限制
    
    - 只输出判断结果，不要输出任何解释
    - 不要输出结果之外的任何内容，确保输出内容可以直接作为Bool值在python语句中运行
    """
    samples = [
        ("user", "告诉我最新的三条政府采购公告"),
        ("assistant", "True"),
      
        ("user", "上海静安音乐节项目的具体信息"),
        ("assistant", "False"),

        ("user", "上海市政府采购中心代理了哪些项目？"),
        ("assistant", "True"),

        ("user", "有关教育的政府采购公告有哪些？"),
        ("assistant", "True"),
        # 还可以在这继续将样本
        # 大模型会从样本中总结出规律，并应用到新对话中
    ]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.utilities import SQLDatabase
from langchain.chains.sql_database.query import create_sql_query_chain

db = SQLDatabase.from_uri("mysql+pymysql://readonly:1234@localhost:3306/xunfei")
gemini_model = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0)
sql_chain = create_sql_query_chain(gemini_model, db, k=10)

def create_sql_query(question, k=10):
    os.environ["HTTPS_PROXY"] = "http://127.0.0.1:7890"
    os.environ["ALL_PROXY"] = "socks5://127.0.0.1:7890"
    sql_chain = create_sql_query_chain(gemini_model, db, k=k)
    response = sql_chain.invoke({"question": question})
    return response

def validate_sql_query(query):
    os.environ["HTTPS_PROXY"] = "http://127.0.0.1:7890"
    os.environ["ALL_PROXY"] = "socks5://127.0.0.1:7890"
    
    system = """Double check the user's {dialect} query for common mistakes, including:
    - Only return SQL Query not anything else like ```sql ... ```
    - Using NOT IN with NULL values
    - Using UNION when UNION ALL should have been used
    - Using BETWEEN for exclusive ranges
    - Data type mismatch in predicates\
    - Using the correct number of arguments for functions
    - Casting to the correct data type
    - Using the proper columns for joins
    
    If there are any of the above mistakes, rewrite the query.
    If there are no mistakes, just reproduce the original query with no further commentary.
    
    Output the final SQL query only."""
    
    prompt = ChatPromptTemplate.from_messages(
        [("system", system), ("human", "{query}")]
    ).partial(dialect=db.dialect)
    
    validation_chain = prompt | gemini_model | StrOutputParser()
    query = validation_chain.invoke({"query": query})
    query = query.replace('```sql', '').replace('```', '')
    return query

def recognise(intent):
    if 'unknown' in intent:
# Out:
# ```sql
# SELECT
#   `公告标题`
# FROM `上海政府采购公告`
# WHERE
#   `公告标题` LIKE '%教育%';
# ```

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

system = """Double check the user's {dialect} query for common mistakes, including:
- Only return SQL Query not anything else like ```sql ... ```
- DELETE ```sql IN THE BEGINNING AND ``` AT END
- NOT USING MARKDOWN FORMAT
- Using NOT IN with NULL values
- Using UNION when UNION ALL should have been used
- Using BETWEEN for exclusive ranges
- Data type mismatch in predicates\
- Using the correct number of arguments for functions
- Casting to the correct data type
- Using the proper columns for joins

If there are any of the above mistakes, rewrite the query.
If there are no mistakes, just reproduce the original query with no further commentary.

Output the final SQL query only."""

prompt = ChatPromptTemplate.from_messages(
    [("system", system), ("human", "{query}")]
).partial(dialect=db.dialect)

validation_chain = prompt | gemini_model | StrOutputParser()

# %%
full_chain = {"query": sql_chain} | validation_chain
query = full_chain.invoke({"question": "有关教育的政府采购公告有哪些？"})
query = query.replace('```sql', '').replace('```', '')
print(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 full_chain = {"query": sql_chain} | validation_chain
# ----> 2 query = full_chain.invoke({"question": "有关教育的政府采购公告有哪些？"})
#       3 query = query.replace('```sql', '').replace('```', '')
#       4 print(query)
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\base.py:4772, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4758 """Invoke this Runnable synchronously.
#    4759
#    4760 Args:
#    (...)   4769     TypeError: If the Runnable is a coroutine function.
#    4770 """
#    4771 if hasattr(self, "func"):
# -> 4772     return self._call_with_config(
#    4773         self._invoke,
#    4774         input,
#    4775         ensure_config(config),
#    4776         **kwargs,
#    4777     )
#    4778 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4779 raise TypeError(msg)
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\base.py:1940, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1936     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1937     with set_config_context(child_config) as context:
#    1938         output = cast(
#    1939             "Output",
# -> 1940             context.run(
#    1941                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1942                 func,
#    1943                 input_,
#    1944                 config,
#    1945                 run_manager,
#    1946                 **kwargs,
#    1947             ),
#    1948         )
#    1949 except BaseException as e:
#    1950     run_manager.on_chain_error(e)
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\base.py:4630, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4628                 output = chunk
#    4629 else:
# -> 4630     output = call_func_with_variable_args(
#    4631         self.func, input_, config, run_manager, **kwargs
#    4632     )
#    4633 # If the output is a Runnable, invoke it
#    4634 if isinstance(output, Runnable):
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\runnables\config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File D:\Anaconda\envs\eval\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given

# %%
results = db.run(query)
results
# Out:
# "[('上海市黄浦区教育信息中心黄浦区教育数字基座项目的公开招标公告',), ('长宁教育专网出口线路租用及维护的公开招标公告',), ('上海市徐汇区政府采购中心—徐汇区教育局西南位育附属实验学校等学校标准化考场设备采购政府采购项目的公开招标公告',), ('上海市徐汇区教育局新建滨江小学跨学科综合学习空间设备采购项目的公开招标公告',), ('上海市疾病预防控制中心公共卫生在线教育电子化课程制作及培训（0025- 00011879 等编号）的公开招标公告',), ('上海市徐汇区政府采购中心——徐汇区教育局南洋中学育才楼修缮改造配套弱电政府采购项目的公开招标公告',), ('上海市徐汇区教育局青中心南楼等学校设备监理采购项目的公开招标公告',), ('上海市徐汇区教育局瑞德幼儿园金塘园等学校设备监理采购项目的公开招标公告',), ('上海市徐汇区教育局C单元西片区规划学校等学校设备监理采购项目的公开招标公告',), ('上海市徐汇区教育局中国中学等学校考试系统（标准化纸笔考场、英语听说考场)维保和考试保障服务及大修学校考试设备拆装服务项目的公开招标公告',), ('上海市徐汇区教育局校园无线网络扩建政府采购项目的公开招标公告',), ('上海市科技艺术教育中心办公用房物业管理费的公开招标公告',), ('2025年教育系统家具统一采购的公开招标公告',), ('上海市徐汇区教育局华之门地块规划中学等学校心理室设备采购项目的公开招标公告',), ('2025年松江区教育局灯光音响设备采购的公开招标公告',), ('上海市徐汇区政府采购中心——徐汇区教育局新建华之门地块规划中学等学校配套弱电采购项目
文化阵地暨民营经济人士理想信念教育基地(聂云台旧居) 建设的竞争性磋商公告',), ('上海健生教育配置招标有限公司关于高温微波制备-原位结构分析光谱仪的公开招标公告',), ('上海教育认证平台（2025年升级改造）的竞争性磋商公告',), ('上海市浦东教育发展研究院新建工程-BIM服务的公开招标公告',), ('2025年上海市职业教育数字图书馆数字资源征集及安装服务项目的竞争性磋商公告',), ('2025年松江区教育局物业管理服务（第二批）的公开招标公告',), ('一流上海家长学校建设-家庭教育指导师培训的竞争性磋商公告',), ('上海市青浦区教育综合事务中心2025年综合物业项目的公开招标公告',), ('上海市闵行区教育学院2025年教学质量监控阅卷项目的公开招标公告',), ('上海市杨浦区教育局校园保安管理服务项目（试点学校）的公开招标公告',), ('上海市杨浦区教育局杨浦区校园保安管理服务项目（中学）的公开招标公告',), ('上海市杨浦区教育局杨浦区校园保安管理服务项目（幼儿园）的公开招标公告',), ('上海市杨浦区教育局杨浦区校园保安管理服务项目（小学）的公开招标公告',), ('上海学前教育综合管理子系统建设项目（2025年升级改造）的竞争性磋商公告',), ('2025年川沙社区教育中心运营项目的竞争性磋商公告',), ('松江区教育考试标准化考点建设（运维）2025的竞争性磋商公告',), ('2025年静安区教育局出口宽带及校校通链路租赁服务的公开招标公告',), ('2025年嘉定区教育学院物业管理服务的公开招标公告',), ('上海市徐汇区政府采购中心----徐汇区教育局虹梅路街道xh205-08地块规划学校新建工程多联机空调政府采购项目的公开招标公告',), ('上海市徐汇区教育局2025年学生视力普查服务采购项目的公开招标公告',), ('上海市公共安全教育实训基地受训人员餐饮及配送服务的公开招标公告',), ('上海市黄浦区教育信息中心——2025年黄浦教育城域网Internet接入链路租赁服务（三包件）的公开招标公告',), ('松江区教育局互联网出口租用（运维） 的竞争性磋商公告',)]"

# %%
from langchain_community.chat_models import ChatZhipuAI

# 设置接口地址常量，这里使用的是阿里云的接口地址
OPENAI_BASE_URL = "https://dashscope.aliyuncs.com/compatible-mode/v1"

# 设置 API Key 常量（注意保密）
OPENAI_API_KEY = "sk-..."

llm = ChatOpenAI(
    base_url=OPENAI_BASE_URL,
    api_key=OPENAI_API_KEY,
    model="deepseek-v3",
)

prompt = """
你是一个用户意图识别专家，擅长分析用户对话，并识别出用户的意图。作为一个智能客户系统的关键组件，你的工作是：

1. 分析用户对话，识别出用户的意图。
2. 根据用户的意图，准确输出对应的意图标签。

客服系统支持以下意图：

- 查询订单
- 查询物流
- 查询账户余额
- 查询积分
- 查询优惠券
- 查询商品

## 限制

- 只输出意图标签，不要输出任何解释。
- 不要输出意图标签之外的任何内容。
- 如果无法识别出意图，请输出 `unknown`。
"""

systemPrompts = [
  ("system", prompt),
]

samples = [
  # 积分兑换不支持
  ("user", "积分怎么兑换？"),
  ("assistant", "unknown"),

  # 积分查询
  ("user", "积分什么时候过期？"),
  ("assistant", "查询积分"),

  # 还可以在这继续将样本
  # 大模型会从样本中总结出规律，并应用到新对话中
]

history = []

while True:
    # 获取用户输入
    user_input = input("你：")

    # 调用大模型接口
    result = llm.invoke(systemPrompts + samples + history + [("user", user_input)])

    # 输出大模型接口的返回结果
    print("AI：", result.content)

    # 更新对话历史（只保留最后10条，即5轮对话历史）
    history.extend([
      ("user", user_input),
      ("assistant", result.content),
    ])
